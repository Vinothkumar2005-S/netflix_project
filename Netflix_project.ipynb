# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv(r"E:\data sets\netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
## data cleaning
df1.isnull().sum()
df1.dtypes
df1.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df1 = df.fillna('Nill')
df1
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water             Nill
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             Nill
# 4         s5  TV Show           Kota Factory             Nill
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb             Nill
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                  Nill  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df1.count(axis = 0)
# Out:
# show_id         8807
# type            8807
# title           8807
# director        8807
# cast            8807
# country         8807
# date_added      8807
# release_year    8807
# rating          8807
# duration        8807
# listed_in       8807
# description     8807
# dtype: int64

# %%
## filter functions 
df_filtered = df1.query("type == 'TV Show'")
df_filtered
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water             Nill
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             Nill
# 4         s5  TV Show           Kota Factory             Nill
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V             Nill
# 8796   s8797  TV Show             Yunus Emre             Nill
# 8797   s8798  TV Show              Zak Storm             Nill
# 8800   s8801  TV Show     Zindagi Gulzar Hai             Nill
# 8803   s8804  TV Show            Zombie Dumb             Nill
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df_filtered1 = df1.query("release_year >= 2018")
df_filtered1
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water             Nill
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             Nill
# 4         s5  TV Show           Kota Factory             Nill
# ...      ...      ...                    ...              ...
# 8752   s8753    Movie               Wish Man      Theo Davies
# 8756   s8757    Movie              Woodstock    Barak Goodman
# 8774   s8775    Movie              يوم الدين  Abu Bakr Shawky
# 8775   s8776  TV Show        Yeh Meri Family             Nill
# 8803   s8804  TV Show            Zombie Dumb             Nill
#
#                                                    cast  \
# 0                                                  Nill
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
## str operations 
df1.columns= df1.columns.str.lower()
df1.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
## exploring datas 

df1.head();
df1.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb             Nill
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                               Nill           Nill
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df1.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df1.loc[12];
df1.iloc[12]
# Out:
# show_id                                                       s13
# type                                                        Movie
# title                                                Je Suis Karl
# director                                      Christian Schwochow
# cast            Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# country                                   Germany, Czech Republic
# date_added                                     September 23, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                  127 min
# listed_in                            Dramas, International Movies
# description     After most of her family is murdered in a terr...
# Name: 12, dtype: object

# %%
df1.to_excel('C:\\Users\\Admin\\OneDrive\\vk_salesdata.xlsx', index = False)

# %%
import pymysql
from sqlalchemy import create_engine

engine_mysql = create_engine("mysql+pymysql://root:2005@127.0.0.1:3306/Netflix")

try:
    create_engine
    print("engine sucessfully active")
except:
    print("unable to connect")
# Out:
# engine sucessfully active

# %%
df1.to_sql('Netflix',con = engine_mysql , if_exists = 'append', index = False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5520\2291819698.py:1: UserWarning: The provided table name 'Netflix' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df1.to_sql('Netflix',con = engine_mysql , if_exists = 'append', index = False)
# 8807
